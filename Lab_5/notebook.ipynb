# %%
import pandas as pd
data = pd.read_csv('table_task.csv')

# %%
data1 = pd.read_csv('table_error1.csv')
data1
# Out:
#          j  x[j]     F[xj]     S[xj]  F[xj] - S[xj]
# 0      0.0  2.00  0.957388  0.957388   1.110223e-16
# 1      1.0  2.01  0.863130  0.862380   7.497005e-04
# 2      2.0  2.02  0.765730  0.765730   0.000000e+00
# 3      3.0  2.03  0.666152  0.666352   2.000213e-04
# 4      4.0  2.04  0.565379  0.565379   0.000000e+00
# ..     ...   ...       ...       ...            ...
# 196  196.0  3.96  0.080265  0.080265   0.000000e+00
# 197  197.0  3.97 -0.013070 -0.013397   3.264657e-04
# 198  198.0  3.98 -0.102238 -0.102238   0.000000e+00
# 199  199.0  3.99 -0.186353 -0.185125   1.227415e-03
# 200  200.0  4.00 -0.264579 -0.264579   0.000000e+00
#
# [201 rows x 5 columns]
